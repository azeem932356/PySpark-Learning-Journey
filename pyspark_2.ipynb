# %% [markdown]
# #### There many ways to read a file
#
# spark.read.csv('')
#
# spark.read.options('', '').csv('')

# %%
#First create sparksession

from pyspark.sql import SparkSession

# %%
spark= SparkSession.builder.appName("Dataframe").getOrCreate()
# Out:
# C:\Users\Shaik\anaconda3\envs\pyspark\Lib\site-packages\pyspark\testing\utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Azeem:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#reading files

df_pyspark= spark.read.csv(
    "datasets/test1.csv",
    header= True, 
    inferSchema=True
)

# %%
df_pyspark.show(4)
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# +---------+---+----------+------+
# only showing top 4 rows

# %% [markdown]
# #### OR

# %%
df_pyspark= spark.read.option('header', 'True').csv('datasets/test1.csv')

# %%
df_pyspark.show(3)
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# +---------+---+----------+------+
# only showing top 3 rows

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %% [markdown]
# ##### You can look above Name, age, Experience, Salary all in String format if we want to do any others they will get error, because we can't do mathamatical operations on strings so what we do is conver them to their respected form, simple way to do is while read passing " inferSchema= True " or in production we manually do that for now simple

# %%
df_pyspark= spark.read.option('header', 'True').csv('datasets/test1.csv', inferSchema= True)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %% [markdown]
# ##### Know you can see they all changed to desired values {" Spark checks and validates and gives their respected type}

# %%
#There is an another way of doing this as well reading
df_pyspark= spark.read.csv("datasets/test1.csv", header= True, inferSchema= True)
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
#To check columns
df_pyspark.columns
# Out:
# ['Name', 'age', 'Experience', 'Salary']

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Krish', age=31, Experience=10, Salary=30000),
#  Row(Name='Sudhanshu', age=30, Experience=8, Salary=25000),
#  Row(Name='Sunny', age=29, Experience=4, Salary=20000)]

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
df_pyspark.select('Name')
# Out:
# DataFrame[Name: string]

# %%
df_pyspark.select('Name').show()
# Out:
# +---------+
# |     Name|
# +---------+
# |    Krish|
# |Sudhanshu|
# |    Sunny|
# |     Paul|
# |   Harsha|
# |  Shubham|
# +---------+

# %%
#Selecting multiple columns

df_pyspark.select(['Name', 'age']).show()
# Out:
# +---------+---+
# |     Name|age|
# +---------+---+
# |    Krish| 31|
# |Sudhanshu| 30|
# |    Sunny| 29|
# |     Paul| 24|
# |   Harsha| 21|
# |  Shubham| 23|
# +---------+---+

# %%
df_pyspark['Name'] # Is not gonna work it is not pandas
# Out:
# Column<'Name'>

# %%
#checking data types

df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
#describe like pandas

df_pyspark.describe().show()
# Out:
# +-------+------+------------------+-----------------+------------------+
# |summary|  Name|               age|       Experience|            Salary|
# +-------+------+------------------+-----------------+------------------+
# |  count|     6|                 6|                6|                 6|
# |   mean|  NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev|  NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|Harsha|                21|                1|             15000|
# |    max| Sunny|                31|               10|             30000|
# +-------+------+------------------+-----------------+------------------+

# %%
df_pyspark.select('age').describe().show()
# Out:
# +-------+------------------+
# |summary|               age|
# +-------+------------------+
# |  count|                 6|
# |   mean|26.333333333333332|
# | stddev| 4.179314138308661|
# |    min|                21|
# |    max|                31|
# +-------+------------------+

# %%
import pandas as pd

# %%
df_road= pd.read_csv('datasets/test1.csv')
df_road.head(3)
# Out:
#         Name  age  Experience  Salary
# 0      Krish   31          10   30000
# 1  Sudhanshu   30           8   25000
# 2      Sunny   29           4   20000

# %%
df_road['age'].describe()
# Out:
# count     6.000000
# mean     26.333333
# std       4.179314
# min      21.000000
# 25%      23.250000
# 50%      26.500000
# 75%      29.750000
# max      31.000000
# Name: age, dtype: float64

# %%
df_pyspark.columns
# Out:
# ['Name', 'age', 'Experience', 'Salary']

# %%
#Addding columns and values
df_pyspark= df_pyspark.withColumn('Experrince After 2_years', df_pyspark['Experience']+2)
df_pyspark.show()
# Out:
# +---------+---+----------+------+------------------------+
# |     Name|age|Experience|Salary|Experrince After 2_years|
# +---------+---+----------+------+------------------------+
# |    Krish| 31|        10| 30000|                      12|
# |Sudhanshu| 30|         8| 25000|                      10|
# |    Sunny| 29|         4| 20000|                       6|
# |     Paul| 24|         3| 20000|                       5|
# |   Harsha| 21|         1| 15000|                       3|
# |  Shubham| 23|         2| 18000|                       4|
# +---------+---+----------+------+------------------------+

# %%
df_pyspark= df_pyspark.withColumn('Salary_Incriment', df_pyspark['Salary']+1000)
df_pyspark.show()
# Out:
# +---------+---+----------+------+------------------------+----------------+
# |     Name|age|Experience|Salary|Experrince After 2_years|Salary_Incriment|
# +---------+---+----------+------+------------------------+----------------+
# |    Krish| 31|        10| 30000|                      12|           31000|
# |Sudhanshu| 30|         8| 25000|                      10|           26000|
# |    Sunny| 29|         4| 20000|                       6|           21000|
# |     Paul| 24|         3| 20000|                       5|           21000|
# |   Harsha| 21|         1| 15000|                       3|           16000|
# |  Shubham| 23|         2| 18000|                       4|           19000|
# +---------+---+----------+------+------------------------+----------------+

# %%
#Now droping columns drop() function take single or multiple columns also
df_pyspark.drop('Experrince After 2_years').show()
# Out:
# +---------+---+----------+------+----------------+
# |     Name|age|Experience|Salary|Salary_Incriment|
# +---------+---+----------+------+----------------+
# |    Krish| 31|        10| 30000|           31000|
# |Sudhanshu| 30|         8| 25000|           26000|
# |    Sunny| 29|         4| 20000|           21000|
# |     Paul| 24|         3| 20000|           21000|
# |   Harsha| 21|         1| 15000|           16000|
# |  Shubham| 23|         2| 18000|           19000|
# +---------+---+----------+------+----------------+

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+------------------------+----------------+
# |     Name|age|Experience|Salary|Experrince After 2_years|Salary_Incriment|
# +---------+---+----------+------+------------------------+----------------+
# |    Krish| 31|        10| 30000|                      12|           31000|
# |Sudhanshu| 30|         8| 25000|                      10|           26000|
# |    Sunny| 29|         4| 20000|                       6|           21000|
# |     Paul| 24|         3| 20000|                       5|           21000|
# |   Harsha| 21|         1| 15000|                       3|           16000|
# |  Shubham| 23|         2| 18000|                       4|           19000|
# +---------+---+----------+------+------------------------+----------------+

# %%
df_pyspark= df_pyspark.drop('Experrince After 2_years', 'Salary_Incriment')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
#Renaming columns

df_pyspark.withColumnRenamed('Name', 'NewName').show()
# Out:
# +---------+---+----------+------+
# |  NewName|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+
