# %%
import pyspark

print(pyspark.__version__)
# Out:
# 4.2.0

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("PySpark Learning") \
    .getOrCreate()

print(spark.version)
# Out:
# C:\Users\Shaik\anaconda3\envs\pyspark\Lib\site-packages\pyspark\testing\utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()
# 4.2.0

# %%
#If we want to read with pandas

import pandas as pd
pd.read_csv("datasets/test1.csv")
# Out:
#         Name  age  Experience  Salary
# 0      Krish   31          10   30000
# 1  Sudhanshu   30           8   25000
# 2      Sunny   29           4   20000
# 3       Paul   24           3   20000
# 4     Harsha   21           1   15000
# 5    Shubham   23           2   18000

# %%
#But with PySpark it is different 1. First we need start sparksession

# Python --->   Sparksession -->  Spark ---> Data

#Initialize spark session

from pyspark.sql import SparkSession

# %%
spark= SparkSession.builder.appName("Practise").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Azeem:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySpark Learning</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#reading data  --> we use show()   how we used in pandas.head()

df_pyspark= spark.read.csv("datasets/test1.csv", header= True)
df_pyspark.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.printSchema()   #--> is kind of pd.info()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %% [markdown]
# #### we can read the data multiple ways

# %%
#starting Spark Session
from pyspark.sql import SparkSession

# %%
spark= SparkSession.builder.appName('Dataframe').getOrCreate()
spark
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 spark= SparkSession.builder.appName('Dataframe').getOrCreate()
#       2 spark
#
# File ~\anaconda3\envs\pyspark\Lib\site-packages\pyspark\sql\session.py:564, in SparkSession.Builder.getOrCreate(self)
#     562     session = SparkSession(sc, options=self._options)
#     563 else:
# --> 564     module = SparkSession._get_j_spark_session_module(session._jvm)
#     565     module.applyModifiableSettings(session._jsparkSession, self._options)
#     566 return session
#
# File ~\anaconda3\envs\pyspark\Lib\site-packages\pyspark\sql\session.py:697, in SparkSession._get_j_spark_session_module(jvm)
#     695 @staticmethod
#     696 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 697     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# ...
